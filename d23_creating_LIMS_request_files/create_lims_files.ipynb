# %%
import io

for i in range(660):

    filename = "dir1_600_requests/request" + str(i).zfill(3) + ".request"
    print(filename)
    with open(filename, 'w') as file:
        field1 = "ORDER"
        field2 = "sqalims" + str(i).zfill(3)
        field3 = ""
        field4 = "winsor01"
        field5 = ""
        field6 = ""
        field7 = ""
        field8 = ""
        
        request = field1 + "," + field2 + "," + field3 + "," + field4 + "," + field5 + "," + field6 + "," + field7 + "," + field8 + ","
        file.write(request)
# Out:
# dir1_600_requests/request000.request
# dir1_600_requests/request001.request
# dir1_600_requests/request002.request
# dir1_600_requests/request003.request
# dir1_600_requests/request004.request
# dir1_600_requests/request005.request
# dir1_600_requests/request006.request
# dir1_600_requests/request007.request
# dir1_600_requests/request008.request
# dir1_600_requests/request009.request
# dir1_600_requests/request010.request
# dir1_600_requests/request011.request
# dir1_600_requests/request012.request
# dir1_600_requests/request013.request
# dir1_600_requests/request014.request
# dir1_600_requests/request015.request
# dir1_600_requests/request016.request
# dir1_600_requests/request017.request
# dir1_600_requests/request018.request
# dir1_600_requests/request019.request
# dir1_600_requests/request020.request
# dir1_600_requests/request021.request
# dir1_600_requests/request022.request
# dir1_600_requests/request023.request
# dir1_600_requests/request024.request
# ...

# %%
import io

filename = "dir2_request_of_600/bigrequest.request"
print(filename)
with open(filename, 'w') as file:
    
    for i in range(660):

        field1 = "ORDER"
        field2 = "sqalims" + str(i).zfill(3)
        field3 = ""
        field4 = "winsor01"
        field5 = ""
        field6 = ""
        field7 = ""
        field8 = ""
        
        request = field1 + "," + field2 + "," + field3 + "," + field4 + "," + field5 + "," + field6 + "," + field7 + "," + field8 + ","
        file.write(request)
        file.write("\n")
        
print("done")
# Out:
# dir2_request_of_600/bigrequest.request
# done

# %%
print(5)
# Out:
# 5
