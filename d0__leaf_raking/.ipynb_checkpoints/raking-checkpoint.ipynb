# %%
import pandas as pd

xls = pd.ExcelFile("appointments_2015.xls")

sheetX = xls.parse(0) #2 is the sheet number

sheetX.head()
# Out:
#         Date          Start time         Finish time           Title  \
# 0 2015-11-14  11/14/2015 11:00am  11/14/2015 12:00pm  1 hr time slot
# 1 2015-11-14  11/14/2015 11:00am  11/14/2015 12:00pm  1 hr time slot
# 2 2015-11-14  11/14/2015 11:00am  11/14/2015 12:00pm  1 hr time slot
# 3 2015-11-14  11/14/2015 12:30pm   11/14/2015 2:30pm  2 hr time slot
# 4 2015-11-14  11/14/2015 12:30pm   11/14/2015 2:30pm  2 hr time slot
#
#   Description  Capacity  Total         Full name         Phone  \
# 0         NaN         3      3     Todd Fenniman  978-266-3734
# 1         NaN         3      3  Terra Friedrichs  978 808 7173
# 2         NaN         3      3    Mario Cardenas  978.456.9305
# 3         NaN         3      3  Susan Cohn-Child  978-635-5322
# 4         NaN         3      3       Dave Harpur  978-772-3311
#
#                                     Address  \
# 0          29 Kinsley Road\nActon, MA 01720
# 1                2 Wright Terrace Acton, MA
# ...

# %%
import time
import datetime
from datetime import date
today = date.today()

startTime = sheetX['Start time']
print(startTime[1])

foo = datetime.datetime.strptime('03:55', '%H:%M').time()
print(foo)
foo = datetime.datetime.strptime('11/14/2015 11:00am', '%m/%d/%Y %I:%M%p').time()
print(foo)
foo = datetime.datetime.strptime('11/14/2015 11:00pm', '%m/%d/%Y %I:%M%p')
print(foo)

#str(foo)


#startTimeObj = date.fromtimestamp(startTime[1])

#startTimeObj

#print(vStartTime[1]) #1 is the row number...
#print(wStarttime[1])
# Out:
# 11/14/2015 11:00am
# 03:55:00
# 11:00:00
# 2015-11-14 23:00:00

# %%
sheetX.describe()
# Out:
#         Capacity      Total
# count  95.000000  95.000000
# mean    3.547368   3.547368
# std     1.419982   1.419982
# min     1.000000   1.000000
# 25%     3.000000   3.000000
# 50%     3.000000   3.000000
# 75%     4.000000   4.000000
# max     7.000000   7.000000
